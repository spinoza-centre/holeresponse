# %%
from fmriprep import config
import os
import nibabel as nb
from nipype.interfaces.fsl import Split as FSLSplit
from nipype.pipeline import engine as pe
from nipype.interfaces import utility as niu
from niworkflows.utils.connections import pop_file, listify
from fmriprep.interfaces import DerivativesDataSink
from fmriprep.interfaces.reports import FunctionalSummary

# BOLD workflows
from fmriprep.workflows.bold.confounds import init_bold_confs_wf, init_carpetplot_wf
from fmriprep.workflows.bold.hmc import init_bold_hmc_wf
from fmriprep.workflows.bold.registration import init_bold_t1_trans_wf, init_bold_reg_wf
from fmriprep.workflows.bold.resampling import (
    init_bold_std_trans_wf,
    init_bold_preproc_trans_wf,
)
# from fmriprep.workflows.bold.outputs import init_func_derivatives_wf
from bids import BIDSLayout
import numpy as np
from fmriprep.config import DEFAULT_MEMORY_MIN_GB
import os
from linescanning import transform
from linescanning.fmriprep import bold_confs_wf

# %%
fprep_dir = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/fmriprep"
bold_file = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/fmriprep/sub-008/ses-2/func/sub-008_ses-2_task-SRFi_acq-3DEPI_run-1_desc-preproc_bold.nii.gz"
bold_mask = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/fmriprep/sub-008/ses-2/func/sub-008_ses-2_task-SRFi_acq-3DEPI_run-1_desc-brain_mask.nii.gz"
movpar_file = "/data1/projects/MicroFunc/Jurjen/programs/packages/fmriprep/AgeRF_tdm/fmriprep_wf/single_subject_03_wf/func_preproc_ses_1_task_scenes_run_0_acq_3DEPI_wf/bold_hmc_wf/normalize_motion/motion_params.txt"
rmsd_file = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_hmc_wf/mcflirt/sub-008_ses-2_task-SRFi_run-1_acq-3DEPI_bold_valid_mcf.nii.gz_rel.rms"
t1_mask = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/manual_masks/sub-008/ses-1/sub-008_ses-1_acq-MP2RAGE_desc-brainmask.nii.gz"
t1_tmps = [
    "/data1/projects/MicroFunc/Jurjen/projects/VE-pRF/derivatives/manual_masks/sub-008/ses-1/sub-008_ses-1_acq-MP2RAGE_label-GM_probseg.nii.gz",
    "/data1/projects/MicroFunc/Jurjen/projects/VE-pRF/derivatives/manual_masks/sub-008/ses-1/sub-008_ses-1_acq-MP2RAGE_label-WM_probseg.nii.gz",
    "/data1/projects/MicroFunc/Jurjen/projects/VE-pRF/derivatives/manual_masks/sub-008/ses-1/sub-008_ses-1_acq-MP2RAGE_label-CSF_probseg.nii.gz"]
workdir = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf"
bids_dir = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/fmriprep"
t1_bold_xform = "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/pycortex/sub-008/transforms/sub-008_from-ses1_to-ses2_rec-motion1_desc-genaff.mat"
apply_warp = False

regressors_all_comps = False
regressors_dvars_th = 1.5_mask
        self.bold_confounds_wf.inputs.inputnode.movpar_file     = self.movpar_file
        self.bold_confounds_wf.inputs.inputnode.t1w_mask        = self.t1_mask
        self.bold_confounds_wf.inputs.inputnode.t1w_tpms        = self.t1_tmps
        self.bold_confounds_wf.inputs.inputnode.t1_bold_xform   = self.t1_bold_xform
        self.bold_confounds_wf.inputs.inputnode.rmsd_file       = self.rm
regressors_fd_th = 0.5

# %%
# get bids layout
layout = BIDSLayout(bids_dir, validate=False)

# Extract metadata
all_metadata = [layout.get_metadata(fname) for fname in listify(bold_file)]

# Take first file as reference
boldref = pop_file(bold_file)
metadata = all_metadata[0]

if os.path.isfile(boldref):
    bold_tlen, mem_gb = bold_confs_wf._create_mem_gb(boldref)

# %%
# get confounds
bold_confounds_wf = init_bold_confs_wf(
    mem_gb=mem_gb,
    metadata=metadata,
    regressors_all_comps=regressors_all_comps,
    regressors_fd_th=regressors_dvars_th,
    regressors_dvars_th=regressors_fd_th,
    name="bold_confounds_wf",
)

# this is necessary for the reports!
bold_confounds_wf.get_node("inputnode").inputs.t1_transform_flags = [False]
for node in bold_confounds_wf.list_node_names():
    if node.split(".")[-1].startswith("ds_report"):
        bold_confounds_wf.get_node(node).inputs.base_directory = fprep_dir
        bold_confounds_wf.get_node(node).inputs.source_file = boldref

# apply T1w > BOLD transformation to T1w mask
if apply_warp:
    bold_mask = transform.ants_applytrafo(
        bold_file, 
        t1_mask, 
        trafo=t1_bold_xform, 
        invert=0, 
        interp='mul', 
        output=bold_mask, 
        return_type="file", 
        verbose=False)

# %%
# set inputs
bold_confounds_wf.inputs.inputnode.bold = bold_file
bold_confounds_wf.inputs.inputnode.bold_mask = bold_mask
bold_confounds_wf.inputs.inputnode.movpar_file = movpar_file
bold_confounds_wf.inputs.inputnode.t1w_mask = t1_mask
bold_confounds_wf.inputs.inputnode.t1w_tpms = t1_tmps
bold_confounds_wf.inputs.inputnode.t1_bold_xform = t1_bold_xform
bold_confounds_wf.inputs.inputnode.rmsd_file = rmsd_file

# set workdir
bold_confounds_wf.base_dir = workdir

# %%
res = bold_confounds_wf.run()
# Out:
# 230608-12:46:00,523 nipype.workflow INFO:
# 	 Workflow bold_confounds_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 230608-12:46:00,633 nipype.workflow INFO:
# 	 Running serially.
# 230608-12:46:00,634 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.dvars" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/dvars".
# 230608-12:46:00,638 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.dvars" - collecting precomputed outputs
# 230608-12:46:00,639 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.dvars" found cached.
# 230608-12:46:00,639 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.fdisp" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/fdisp".
# 230608-12:46:00,642 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.fdisp" - collecting precomputed outputs
# 230608-12:46:00,643 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.fdisp" found cached.
# 230608-12:46:00,643 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.t1w_mask_tfm" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/t1w_mask_tfm".
# 230608-12:46:00,647 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.t1w_mask_tfm" - collecting precomputed outputs
# 230608-12:46:00,648 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.t1w_mask_tfm" found cached.
# 230608-12:46:00,648 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.acc_masks" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_masks".
# 230608-12:46:00,652 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.acc_masks" - collecting precomputed outputs
# 230608-12:46:00,652 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.acc_masks" found cached.
# 230608-12:46:00,653 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.tcompcor" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/tcompcor".
# 230608-12:46:00,656 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.tcompcor" - collecting precomputed outputs
# 230608-12:46:00,657 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.tcompcor" found cached.
# 230608-12:46:00,658 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.add_motion_headers" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/add_motion_headers".
# 230608-12:46:00,660 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.add_motion_headers" - collecting precomputed outputs
# 230608-12:46:00,661 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.add_motion_headers" found cached.
# 230608-12:46:00,662 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.add_rmsd_header" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/add_rmsd_header".
# 230608-12:46:00,665 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.add_rmsd_header" - collecting precomputed outputs
# 230608-12:46:00,665 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.add_rmsd_header" found cached.
# 230608-12:46:00,666 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.add_dvars_header" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/add_dvars_header".
# 230608-12:46:00,671 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.add_dvars_header" - collecting precomputed outputs
# 230608-12:46:00,671 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.add_dvars_header" found cached.
# 230608-12:46:00,672 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.add_std_dvars_header" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/add_std_dvars_header".
# 230608-12:46:00,676 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.add_std_dvars_header" - collecting precomputed outputs
# 230608-12:46:00,677 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.add_std_dvars_header" found cached.
# 230608-12:46:00,677 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.union_mask" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/union_mask".
# 230608-12:46:00,682 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.union_mask" - collecting precomputed outputs
# 230608-12:46:00,682 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.union_mask" found cached.
# 230608-12:46:00,689 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.acc_msk_tfm" found cached.
# 230608-12:46:00,690 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.tcc_metadata_filter" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/tcc_metadata_filter".
# 230608-12:46:00,694 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.tcc_metadata_filter" - collecting precomputed outputs
# 230608-12:46:00,695 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.tcc_metadata_filter" found cached.
# 230608-12:46:00,695 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.dilated_mask" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/dilated_mask".
# 230608-12:46:00,700 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.dilated_mask" - collecting precomputed outputs
# 230608-12:46:00,700 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.dilated_mask" found cached.
# 230608-12:46:00,706 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.acc_msk_brain" found cached.
# 230608-12:46:00,707 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.tcc_metadata_fmt" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/tcc_metadata_fmt".
# 230608-12:46:00,711 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.tcc_metadata_fmt" - collecting precomputed outputs
# 230608-12:46:00,712 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.tcc_metadata_fmt" found cached.
# 230608-12:46:00,713 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.subtract_mask" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/subtract_mask".
# 230608-12:46:00,718 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.subtract_mask" - collecting precomputed outputs
# 230608-12:46:00,718 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.subtract_mask" found cached.
# 230608-12:46:00,725 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.acc_msk_bin" found cached.
# 230608-12:46:00,725 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.crowncompcor" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/crowncompcor".
# 230608-12:46:00,731 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.crowncompcor" - collecting precomputed outputs
# 230608-12:46:00,732 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.crowncompcor" found cached.
# 230608-12:46:00,733 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.acompcor" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acompcor".
# 230608-12:46:00,740 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.acompcor" - collecting precomputed outputs
# 230608-12:46:00,740 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.acompcor" found cached.
# 230608-12:46:00,741 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.merge_rois" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/merge_rois".
# 230608-12:46:00,749 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.merge_rois" - collecting precomputed outputs
# 230608-12:46:00,750 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.merge_rois" found cached.
# 230608-12:46:00,750 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.mrg_compcor" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/mrg_compcor".
# 230608-12:46:00,758 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.mrg_compcor" - collecting precomputed outputs
# 230608-12:46:00,758 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.mrg_compcor" found cached.
# 230608-12:46:00,759 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.crowncc_metadata_fmt" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/crowncc_metadata_fmt".
# 230608-12:46:00,770 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.crowncc_metadata_fmt" - collecting precomputed outputs
# 230608-12:46:00,771 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.crowncc_metadata_fmt" found cached.
# 230608-12:46:00,772 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.rename_acompcor" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/rename_acompcor".
# 230608-12:46:00,777 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.rename_acompcor" - collecting precomputed outputs
# 230608-12:46:00,778 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.rename_acompcor" found cached.
# 230608-12:46:00,779 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.merge_compcor_metadata" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/merge_compcor_metadata".
# 230608-12:46:00,786 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.merge_compcor_metadata" - collecting precomputed outputs
# 230608-12:46:00,787 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.merge_compcor_metadata" found cached.
# 230608-12:46:00,788 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.signals" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/signals".
# 230608-12:46:00,793 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.signals" - collecting precomputed outputs
# 230608-12:46:00,794 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.signals" found cached.
# 230608-12:46:00,795 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.rois_plot" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/rois_plot".
# 230608-12:46:00,800 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.rois_plot" - collecting precomputed outputs
# 230608-12:46:00,800 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.rois_plot" found cached.
# 230608-12:46:00,801 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.acc_metadata_filter" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_metadata_filter".
# 230608-12:46:00,805 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.acc_metadata_filter" - collecting precomputed outputs
# 230608-12:46:00,805 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.acc_metadata_filter" found cached.
# 230608-12:46:00,806 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.compcor_plot" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/compcor_plot".
# 230608-12:46:00,811 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.compcor_plot" - collecting precomputed outputs
# 230608-12:46:00,811 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.compcor_plot" found cached.
# 230608-12:46:00,812 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.concat" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/concat".
# 230608-12:46:00,827 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.concat" - collecting precomputed outputs
# 230608-12:46:00,827 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.concat" found cached.
# 230608-12:46:00,828 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.ds_report_bold_rois" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/ds_report_bold_rois".
# 230608-12:46:00,845 nipype.workflow INFO:
# 	 [Node] Executing "ds_report_bold_rois" <fmriprep.interfaces.DerivativesDataSink>
# 230608-12:46:00,857 nipype.workflow INFO:
# 	 [Node] Finished "ds_report_bold_rois", elapsed time 0.01028s.
# 230608-12:46:00,867 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.acc_metadata_fmt" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_metadata_fmt".
# 230608-12:46:00,871 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.acc_metadata_fmt" - collecting precomputed outputs
# 230608-12:46:00,872 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.acc_metadata_fmt" found cached.
# 230608-12:46:00,872 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.ds_report_compcor" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/ds_report_compcor".
# 230608-12:46:00,889 nipype.workflow INFO:
# 	 [Node] Executing "ds_report_compcor" <fmriprep.interfaces.DerivativesDataSink>
# 230608-12:46:00,900 nipype.workflow INFO:
# 	 [Node] Finished "ds_report_compcor", elapsed time 0.008841s.
# 230608-12:46:00,910 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.model_expansion" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/model_expansion".
# 230608-12:46:00,914 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.model_expansion" - collecting precomputed outputs
# 230608-12:46:00,914 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.model_expansion" found cached.
# 230608-12:46:00,915 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.conf_corr_plot" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/conf_corr_plot".
# 230608-12:46:00,928 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.conf_corr_plot" - collecting precomputed outputs
# 230608-12:46:00,928 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.conf_corr_plot" found cached.
# 230608-12:46:00,929 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.merge_confound_metadata" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/merge_confound_metadata".
# 230608-12:46:00,974 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.merge_confound_metadata" - collecting precomputed outputs
# 230608-12:46:00,975 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.merge_confound_metadata" found cached.
# 230608-12:46:00,975 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.spike_regressors" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/spike_regressors".
# 230608-12:46:00,980 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.spike_regressors" - collecting precomputed outputs
# 230608-12:46:00,980 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.spike_regressors" found cached.
# 230608-12:46:00,981 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.ds_report_conf_corr" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/ds_report_conf_corr".
# 230608-12:46:00,997 nipype.workflow INFO:
# 	 [Node] Executing "ds_report_conf_corr" <fmriprep.interfaces.DerivativesDataSink>
# 230608-12:46:01,9 nipype.workflow INFO:
# 	 [Node] Finished "ds_report_conf_corr", elapsed time 0.009776s.
# 230608-12:46:01,18 nipype.workflow INFO:
# 	 [Node] Setting-up "bold_confounds_wf.merge_confound_metadata2" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/merge_confound_metadata2".
# 230608-12:46:01,59 nipype.workflow INFO:
# 	 [Node] Cached "bold_confounds_wf.merge_confound_metadata2" - collecting precomputed outputs
# 230608-12:46:01,59 nipype.workflow INFO:
# 	 [Node] "bold_confounds_wf.merge_confound_metadata2" found cached.

# %%
def init_func_derivatives_wf(
    bids_dir=None,
    workdir=None
    ):

    from fmriprep.interfaces import DerivativesDataSink
    from nipype.pipeline import engine as pe
    from niworkflows.engine.workflows import LiterateWorkflow as Workflow
    from nipype.interfaces import utility as niu
    from smriprep.workflows.outputs import _bids_relative

    name='func_derivatives_wf'
    workflow = Workflow(name=name)

    inputnode = pe.Node(
        niu.IdentityInterface(
            fields=[
                'source_file',
                'all_source_files',
                'confounds',
                'confounds_metadata',
                'anat2bold_xfm',
                'acompcor_masks',
                'tcompcor_mask',
            ]
        ),
        name='inputnode',
    )

    raw_sources = pe.Node(niu.Function(function=_bids_relative), name='raw_sources')
    raw_sources.inputs.bids_root = fprep_dir

    ds_confounds = pe.Node(
        DerivativesDataSink(
            base_directory=fprep_dir,
            desc='confounds',
            suffix='timeseries',
            dismiss_entities=("echo",),
        ),
        name="ds_confounds",
        run_without_submitting=True,
        mem_gb=config.DEFAULT_MEMORY_MIN_GB,
    )
    ds_ref_t1w_xfm = pe.Node(
        DerivativesDataSink(
            base_directory=fprep_dir,
            to='T1w',
            mode='image',
            suffix='xfm',
            extension='.txt',
            dismiss_entities=('echo',),
            **{'from': 'scanner'},
        ),
        name='ds_ref_t1w_xfm',
        run_without_submitting=True,
    )
    ds_ref_t1w_inv_xfm = pe.Node(
        DerivativesDataSink(
            base_directory=fprep_dir,
            to='scanner',
            mode='image',
            suffix='xfm',
            extension='.txt',
            dismiss_entities=('echo',),
            **{'from': 'T1w'},
        ),
        name='ds_t1w_tpl_inv_xfm',
        run_without_submitting=True,
    )

    workflow.connect([
        (inputnode, raw_sources, [('all_source_files', 'in_files')]),
        (inputnode, ds_confounds, [('source_file', 'source_file'),
                                    ('confounds', 'in_file'),
                                    ('confounds_metadata', 'meta_dict')]),
        (inputnode, ds_ref_t1w_inv_xfm, [('source_file', 'source_file'),
                                            ('anat2bold_xfm', 'in_file')]),
    ])

    return workflow

# %%
def fetch_output(wf, node, key, graph=None):

    # convert nodes in graph to strings 
    str_nodes = [str(ii) for ii in list(graph.nodes)]

    # then look for index in string-version of nodes
    nn = f'{wf}.{node}'
    ix_rel = str_nodes.index(nn)

    # and fetch the node from the original graph
    try:
        out = list(res.nodes)[ix_rel].result.outputs.get()[key]
    except:
        out = list(res.nodes)[ix_rel].result.outputs
    
    return out

# %%
fetch_output("bold_confounds_wf", "acc_msk_bin", "out_file", graph=res)
# Out:
# Bunch(out_file=['/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin0/sub-008_ses-1_acq-MP2RAGE_label-CSF_probseg_trans_masked_masked.nii.gz',
#        '/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin1/acompcor_wm_trans_masked_masked.nii.gz',
#        '/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin2/acompcor_wmcsf_trans_masked_masked.nii.gz'],
#       out_mask=<undefined>)

# %%
func_derivatives_wf = init_func_derivatives_wf(bids_dir=fprep_dir)

func_derivatives_wf.inputs.inputnode.all_source_files = bold_file
func_derivatives_wf.inputs.inputnode.source_file = bold_file
func_derivatives_wf.inputs.inputnode.confounds = fetch_output("bold_confounds_wf", "spike_regressors", "confounds_file", graph=res)
func_derivatives_wf.inputs.inputnode.confounds_metadata = fetch_output("bold_confounds_wf", "merge_confound_metadata2", "out_dict", graph=res)
func_derivatives_wf.inputs.inputnode.anat2bold_xfm = t1_bold_xform
func_derivatives_wf.inputs.inputnode.tcompcor_mask = fetch_output("bold_confounds_wf", "tcompcor", "high_variance_masks", graph=res)
func_derivatives_wf.inputs.inputnode.acompcor_masks = fetch_output("bold_confounds_wf", "acc_msk_bin", "out_file", graph=res)
func_derivatives_wf.base_dir = workdir

# %%
func_derivatives_wf.inputs.inputnode
# Out:
# acompcor_masks = Bunch(out_file=['/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin0/sub-008_ses-1_acq-MP2RAGE_label-CSF_probseg_trans_masked_masked.nii.gz', '/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin1/acompcor_wm_trans_masked_masked.nii.gz', '/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin2/acompcor_wmcsf_trans_masked_masked.nii.gz'], out_mask=<undefined>)
# all_source_files = /data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/fmriprep/sub-008/ses-2/func/sub-008_ses-2_task-SRFi_acq-3DEPI_run-1_desc-preproc_bold.nii.gz
# anat2bold_xfm = /data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/pycortex/sub-008/transforms/sub-008_from-ses1_to-ses2_rec-motion1_desc-genaff.mat
# confounds = /data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/spike_regressors/confounds_expansion_desc-motion_outliers.tsv
# confounds_metadata = {'t_comp_cor_00': {'SingularValue': 577.9700794618, 'VarianceExplained': 0.4815459848, 'CumulativeVarianceExplained': 0.4815459848, 'Retained': True, 'Method': 'tCompCor'}, 't_comp_cor_01': {'SingularValue': 281.3655014848, 'VarianceExplained': 0.1141218353, 'CumulativeVarianceExplained': 0.5956678202, 'Retained': True, 'Method': 'tCompCor'}, 'c_comp_cor_00': {'Mask': 'CSF', 'SingularValue': 221.7109734431, 'VarianceExplained': 0.19662145, 'CumulativeVarianceExplained': 0.19662145, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_01': {'Mask': 'CSF', 'SingularValue': 148.0326882008, 'VarianceExplained': 0.0876540059, 'CumulativeVarianceExplained': 0.2842754559, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_02': {'Mask': 'CSF', 'SingularValue': 122.6798396435, 'VarianceExplained': 0.0602008906, 'CumulativeVarianceExplained': 0.3444763465, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_03': {'Mask': 'CSF', 'SingularValue': 108.1723112745, 'VarianceExplained': 0.0468046213, 'CumulativeVarianceExplained': 0.3912809678, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_04': {'Mask': 'CSF', 'SingularValue': 86.7921908632, 'VarianceExplained': 0.0301312965, 'CumulativeVarianceExplained': 0.4214122643, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_05': {'Mask': 'CSF', 'SingularValue': 82.0089511338, 'VarianceExplained': 0.0269016571, 'CumulativeVarianceExplained': 0.4483139213, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_06': {'Mask': 'CSF', 'SingularValue': 73.5058456611, 'VarianceExplained': 0.0216122645, 'CumulativeVarianceExplained': 0.4699261858, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_07': {'Mask': 'CSF', 'SingularValue': 68.2764052594, 'VarianceExplained': 0.0186465209, 'CumulativeVarianceExplained': 0.4885727067, 'Retained': True, 'Method': 'aCompCor'}, 'c_comp_cor_08': {'Mask': 'CSF', 'SingularValue': 63.7792216074, 'VarianceExplained': 0.0162710263, 'CumulativeVarianceExplained': 0.504843733, 'Retained': True, 'Method': 'aCompCor'}, 'w_comp_cor_00': {'Mask': 'WM', 'SingularValue': 132.3334693569, 'VarianceExplained': 0.2477456231, 'CumulativeVarianceExplained': 0.2477456231, 'Retained': True, 'Method': 'aCompCor'}, 'w_comp_cor_01': {'Mask': 'WM', 'SingularValue': 75.2037269275, 'VarianceExplained': 0.0800101936, 'CumulativeVarianceExplained': 0.3277558167, 'Retained': True, 'Method': 'aCompCor'}, 'w_comp_cor_02': {'Mask': 'WM', 'SingularValue': 63.5293724441, 'VarianceExplained': 0.05709732, 'CumulativeVarianceExplained': 0.3848531367, 'Retained': True, 'Method': 'aCompCor'}, 'w_comp_cor_03': {'Mask': 'WM', 'SingularValue': 55.530335249, 'VarianceExplained': 0.0436241707, 'CumulativeVarianceExplained': 0.4284773074, 'Retained': True, 'Method': 'aCompCor'}, 'w_comp_cor_04': {'Mask': 'WM', 'SingularValue': 49.2105125131, 'VarianceExplained': 0.0342596065, 'CumulativeVarianceExplained': 0.4627369139, 'Retained': True, 'Method': 'aCompCor'}, 'w_comp_cor_05': {'Mask': 'WM', 'SingularValue': 42.4252637478, 'VarianceExplained': 0.0254633591, 'CumulativeVarianceExplained': 0.488200273, 'Retained': True, 'Method': 'aCompCor'}, 'w_comp_cor_06': {'Mask': 'WM', 'SingularValue': 41.0546067176, 'VarianceExplained': 0.0238446189, 'CumulativeVarianceExplained': 0.5120448919, 'Retained': True, 'Method': 'aCompCor'}, 'a_comp_cor_00': {'Mask': 'combined', 'SingularValue': 132.3334693569, 'VarianceExplained': 0.2477456231, 'CumulativeVarianceExplained': 0.2477456231, 'Retained': True, 'Method': 'aCompCor'}, 'a_comp_cor_01': {'Mask': 'combined', 'SingularValue': 75.2037269275, 'VarianceExplained': 0.0800101936, 'CumulativeVarianceExplained': 0.3277558167, 'Retained': True, 'Method': 'aCompCor'}, 'a_comp_cor_02': {'Mask': 'combined', 'SingularValue': 63.5293724441, 'VarianceExplained': 0.05709732, 'CumulativeVarianceExplained': 0.3848531367, 'Retained': True, 'Method': 'aCompCor'}, 'a_comp_cor_03': {'Mask': 'combined', 'SingularValue': 55.530335249, 'VarianceExplained': 0.04362 ...
# source_file = /data1/projects/MicroFunc/Jurjen/projects/VE-SRF/derivatives/fmriprep/sub-008/ses-2/func/sub-008_ses-2_task-SRFi_acq-3DEPI_run-1_desc-preproc_bold.nii.gz
# tcompcor_mask = /data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/bold_confounds_wf/tcompcor/mask_000.nii.gz

# %%
func_derivatives_wf.run()
# Out:
# 230608-13:24:39,447 nipype.workflow INFO:
# 	 Workflow func_derivatives_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 230608-13:24:39,476 nipype.workflow INFO:
# 	 Running serially.
# 230608-13:24:39,477 nipype.workflow INFO:
# 	 [Node] Setting-up "func_derivatives_wf.raw_sources" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/func_derivatives_wf/raw_sources".
# 230608-13:24:39,480 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "func_derivatives_wf.raw_sources".
# 230608-13:24:39,492 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 230608-13:24:39,495 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000606s.
# 230608-13:24:39,505 nipype.workflow INFO:
# 	 [Node] Setting-up "func_derivatives_wf.ds_confounds" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/func_derivatives_wf/ds_confounds".
# 230608-13:24:39,576 nipype.workflow INFO:
# 	 [Node] Executing "ds_confounds" <fmriprep.interfaces.DerivativesDataSink>
# 230608-13:24:39,598 nipype.workflow INFO:
# 	 [Node] Finished "ds_confounds", elapsed time 0.01914s.
# 230608-13:24:39,619 nipype.workflow INFO:
# 	 [Node] Setting-up "func_derivatives_wf.ds_t1w_tpl_inv_xfm" in "/data1/projects/MicroFunc/Jurjen/projects/VE-SRF/sourcedata/sub-008/ses-2/single_subject_008_wf/func_preproc_ses_2_task_SRFi_run_1_acq_3DEPI_wf/func_derivatives_wf/ds_t1w_tpl_inv_xfm".
# 230608-13:24:39,630 nipype.workflow INFO:
# 	 [Node] Executing "ds_t1w_tpl_inv_xfm" <fmriprep.interfaces.DerivativesDataSink>
# 230608-13:24:39,646 nipype.workflow INFO:
# 	 [Node] Finished "ds_t1w_tpl_inv_xfm", elapsed time 0.013483s.
